# %%
import numpy as np
import matplotlib.pyplot as plt
import obspy 

from obspy.signal.filter import bandpass
from prelude import *
#from matplotlib.axes import Axes

# %%
tr = obspy.read("/scratch/naalexeev/NODAL/2019-03-02T01:00:00.000000Z.2019-03-02T02:00:00.000000Z.1225.mseed")
tr.trim(tr[2].stats.starttime + 42 * 60, tr[0].stats.starttime + 43 * 60 + 45)
tr[2].plot()

# %%
print(tr[2])
fig1, ax1 = plt.subplots()
fig1.set_figwidth(5.0)
#fig1.set_figheight(4.0)
ax1.set_ylim([0, 100])
tr[2].spectrogram(axes = ax1,log=False,dbscale=True,cmap='hsv')
#fig1.show()
# Out:
# ZE.1225..DPZ | 2019-03-02T01:42:00.000000Z - 2019-03-02T01:43:45.000000Z | 500.0 Hz, 52501 samples
# <AxesSubplot:>

# %%
print(tr[2])
fig1, ax1 = plt.subplots()
fig1.set_figwidth(5.0)
fig1.set_figheight(10.0)
ax1.set_xlim([0, 3500])
tr[2].spectrogram(axes = ax1,log=False,dbscale=True,cmap='PiYG_r')
#plt.show()
# Out:
# ZE.1225..DPZ | 2019-03-02T01:42:00.000000Z - 2019-03-02T01:43:45.000000Z | 500.0 Hz, 52501 samples
# <AxesSubplot:>

# %%
print(tr[2])
fig, ax = plt.subplots()
fig.set_figwidth(5.0)
tr[2].spectrogram(axes = ax,log=False,dbscale=True,cmap='plasma_r')
plt.show()
# Out:
# ZE.1225..DPZ | 2019-03-02T01:42:00.000000Z - 2019-03-02T01:43:45.000000Z | 500.0 Hz, 52501 samples

# %%
print(tr[2])
fig1, ax1 = plt.subplots()
fig1.set_figwidth(2.5)
fig1.set_figheight(6)
ax1.set_xlim([0, 3500])
tr[2].spectrogram(axes = ax1,per_lap=0.99,log=False,dbscale=True,cmap='hsv',clip=[0.4, 0.5])
plt.show()
# Out:
# ZE.1225..DPZ | 2019-03-02T01:42:00.000000Z - 2019-03-02T01:43:45.000000Z | 500.0 Hz, 52501 samples

# %%
from datetime import datetime

# input datetime
dt = datetime(2018, 10, 22, 0, 0)
# epoch time
epoch_time = datetime(1970, 1, 1)

# subtract Datetime from epoch datetime
delta = (dt - epoch_time)
print('Datetime to Seconds since epoch:', delta.total_seconds())
#print(tr[2])
fig1, ax1 = plt.subplots()
#ax1 = (tr[2].stats.starttime + 5 * 60, tr[0].stats.starttime + 7 * 60)
#.xaxis_date()
#figure out time
print(tr)
#str() to convert the float to a string before passing it to datetime.strptime()
#fig1.set_figwidth(20.0)
#fig1.set_figheight(12.0)
tr[2].spectrogram(axes = ax1,per_lap=0.99,title=str(tr[2].stats.station+tr[2].stats.channel),log=False,dbscale=True,cmap='gist_rainbow',clip=[0.4, 0.5])
plt.show()
# Out:
# Datetime to Seconds since epoch: 1540166400.0
# 3 Trace(s) in Stream:
# ZE.1225..DP1 | 2019-03-02T01:42:00.000000Z - 2019-03-02T01:43:45.000000Z | 500.0 Hz, 52501 samples
# ZE.1225..DP2 | 2019-03-02T01:42:00.000000Z - 2019-03-02T01:43:45.000000Z | 500.0 Hz, 52501 samples
# ZE.1225..DPZ | 2019-03-02T01:42:00.000000Z - 2019-03-02T01:43:45.000000Z | 500.0 Hz, 52501 samples
